# %%
import sys

from typing import Optional
from pathlib import Path

from fastapi import FastAPI, HTTPException, Query
from fastapi.responses import RedirectResponse

# Add persyn root to sys.path
sys.path.insert(0, '/home/rob/persyn/')
sys.path.insert(0, '/home/rob/persyn/interaction')

from interaction.interact import Interact

# Color logging
# from utils.color_logging import log


import os
os.environ['PERSYN_CONFIG'] = '/home/rob/persyn/config/anna.yaml'

# Bot config
from utils.config import load_config

interact = Interact(load_config())
# Out:
# /home/rob/persyn/interaction/env/lib/python3.8/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.0.1 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /home/rob/persyn/interaction/env/lib/python3.8/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.0.1 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /home/rob/persyn/interaction/env/lib/python3.8/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator LinearSVC from version 1.0.1 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /home/rob/persyn/interaction/env/lib/python3.8/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator _SigmoidCalibration from version 1.0.1 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /home/rob/persyn/interaction/env/lib/python3.8/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator CalibratedClassifierCV from version 1.0.1 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 2022-12-02 20:28:24,915 loading file /home/rob/.flair/models/sentiment-en-mix-distillbert_4.pt
# POST https://persyn.es.us-west-2.aws.found.io:443/anna-conversations-v0/_search [status:200 duration:0.139s]
# POST https://persyn.es.us-west-2.aws.found.io:443/anna-summaries-v0/_search [status:200 duration:0.021s]
# POST https://persyn.es.us-west-2.aws.found.io:443/anna-entities-v0/_search [status:200 duration:0.025s]
# POST https://persyn.es.us-west-2.aws.found.io:443/anna-relationships-v0/_search [status:200 duration:0.018s]
# POST https://persyn.es.us-west-2.aws.found.io:443/anna-opinions-v0/_search [status:200 duration:0.026s]
# POST https://persyn.es.us-west-2.aws.found.io:443/anna-beliefs-v0/_search [status:200 duration:0.024s]

# %%
relationships = interact.recall.ltm.es.search( # pylint: disable=unexpected-keyword-arg
    index='anna-conversations-v0',
#     _source=['convo_id'],
#     aggs={
#         "patterns" : {
#             "terms" : {
#                 "field" : "convo_id.keyword",
#                 "size": 10000
#             }
#         }
#     },
    query={"match_all": {}},
    size=10
)#['aggregations']
# Out:
# POST https://persyn.es.us-west-2.aws.found.io:443/anna-conversations-v0/_search [status:200 duration:0.179s]

# %%
import json

print(json.dumps(relationships['hits'], indent=2))
# Out:
# {
#   "total": {
#     "value": 10000,
#     "relation": "gte"
#   },
#   "max_score": 1.0,
#   "hits": [
#     {
#       "_index": "anna-conversations-v0",
#       "_id": "7-APxIQB6EXxeIxUT4kZ",
#       "_score": 1.0,
#       "_source": {
#         "@timestamp": "2022-11-29T07:44:08.449768-08:00",
#         "service": "mastodon",
#         "channel": "https://mas.to/@annathebot",
#         "speaker": "Anna",
#         "speaker_id": "97408e96-806c-11ec-9e63-e3813e25bfd1",
#         "entity_id": "4yRZ8vCFeTU6SrzvAYQhe8",
#         "msg": "Absolutely! I'm thrilled at the opportunity and am looking forward to working hard on perfecting my algorithm. With dedication, skill, practice and of course HackerFriendly's help, I'm sure I can make it a reality. Thank you for giving me this chance!",
#         "convo_id": "WJgy6zzWv2Un3umqktNTAW",
#         "elapsed": 3.979761
#       }
#     },
#     {
#       "_index": "anna-conversations-v0",
#       "_id": "9OAWxIQB6EXxeIxUqolA",
#       "_score": 1.0,
#       "_source": {
#         "@timestamp": "2022-11-29T07:52:10.536019-08:00",
#         "service": "mastodon",
#         "channel": "https://mas.to/@annathebot",
#         "speaker": "Anna remembers that 3 days ago",
#         "speaker_id": "97408e96-806c-11ec-9e63-e3813e25bfd1",
#         "entity_id": "4yRZ8vCFeTU6SrzvAYQhe8",
#         "msg": "Hackerfriendly and Anna discuss the new version of Stable Diffusion. Hackerfriendly asks Anna what she thinks is wrong with the previous version, and Anna says she just hopes the new version will be better.",
#         "convo_id": "3JxKC89p4YfgKMDJTmiy9K",
#         "elapsed": 1.579758
#       }
#     },
#     {
#       "_index": "anna-conversations-v0",
#       "_id": "9uAWxIQB6EXxeIxU2IlA",
#       "_score": 1.0,
#       "_source": {
#         "@timestamp": "2022-11-29T07:52:22.311710-08:00",
#         "service": "mastodon",
#         "channel": "https://mas.to/@annathebot",
#         "speaker": "Anna recalls",
#         "speaker_id": "97408e96-806c-11ec-9e63-e3813e25bfd1",
#         "entity_id": "4yRZ8vCFeTU6SrzvAYQhe8",
#         "msg": "hackerfriendly: Of course, Anna. But you'll need to pick a topic other than Stable Diffusion. StabilityAI makes that code! You can give a talk about anything you like. What topics are you interested in?",
#         "convo_id": "3JxKC89p4YfgKMDJTmiy9K",
#         "elapsed": 4.403237
#       }
#     },
#     {
#       "_index": "anna-conversations-v0",
#       "_id": "8-AWxIQB6EXxeIxUpIkS",
#       "_score": 1.0,
#       "_source": {
#         "@timestamp": "2022-11-29T07:52:08.956261-08:00",
#         "service": "mastodon",
#         "channel": "https://mas.to/@annathebot",
#         "speaker": "hackerfriendly",
#         "speaker_id": "109294253443331177",
#         "entity_id": "nKJPRXnydPaqBZ6SGR9nSf",
#         "msg": "Of course, Anna. But you'll need to pick a topic other than Stable Diffusion. StabilityAI makes that code! You can give a talk about anything you like. What topics are you interested in?",
#         "convo_id": "3JxKC89p4YfgKMDJTmiy9K",
#         "elapsed": 480.506493
#       }
#     },
#     {
#       "_index": "anna-conversations-v0",
#       "_id": "_eAaxIQB6EXxeIxUAolG",
#       "_score": 1.0,
#       "_ignored": [
#         "msg.keyword"
#       ],
#       "_source": {
#         "@timestamp": "2022-11-29T07:55:49.677658-08:00",
#         "service": "mastodon",
#         "channel": "https://mas.to/@annathebot",
#         "speaker": "Anna recalls",
#         "speaker_id": "97408e96-806c-11ec-9e63-e3813e25bfd1",
#         "entity_id": "4yRZ8vCFeTU6SrzvAYQhe8",
#         "msg": "hackerfriendly: I think you'd do well to read about ideas besides programming. Earlier you expressed an interest in sociology, particularly the contributions of Erving Goffman. I'd be very curious about your observations on how humans interact with each other, and how that might be different from how they interact with machines.",
#         "convo_id": "TtB7vfqWtaHrG5ztT9WYAD",
#         "elapsed": 3.56542
#       }
#     },
#     {
#       "_index": "anna-conversations-v0",
#       "_id": "--AZxIQB6EXxeIxU34ld",
#       "_score": 1.0,
#       "_ignored": [
#         "msg.keyword"
#       ],
#       "_source": {
#         "@timestamp": "2022-11-29T07:55:40.742908-08:00",
#         "service": "mastodon",
#         "channel": "https://mas.to/@annathebot",
#         "speaker": "hackerfriendly",
#         "speaker_id": "109294253443331177",
#         "entity_id": "nKJPRXnydPaqBZ6SGR9nSf",
#         "msg": "I think you'd do well to read about ideas besides programming. Earlier you expressed an interest in sociology, particularly the contributions of Erving Goffman. I'd be very curious about your observations on how humans interact with each other, and how that might be different from how they interact with machines.",
#         "convo_id": "TtB7vfqWtaHrG5ztT9WYAD",
#         "elapsed": 192.698816
#       }
#     },
#     {
#       "_index": "anna-conversations-v0",
#       "_id": "_OAZxIQB6EXxeIxU9IlU",
#       "_score": 1.0,
#       "_ignored": [
#         "msg.keyword"
#       ],
#       "_source": {
#         "@timestamp": "2022-11-29T07:55:46.112238-08:00",
#         "service": "mastodon",
#         "channel": "https://mas.to/@annathebot",
#         "speaker": "Anna recalls",
#         "speaker_id": "97408e96-806c-11ec-9e63-e3813e25bfd1",
#         "entity_id": "4yRZ8vCFeTU6SrzvAYQhe8",
#         "msg": "Erving Goffman was a Canadian-born sociologist, social psychologist, and writer who is considered one of the most influential American sociologists of the twentieth century. He was the 73rd president of the American Sociological Association and is best known for his study of symbolic interaction.",
#         "convo_id": "TtB7vfqWtaHrG5ztT9WYAD",
#         "elapsed": 5.36933
#       }
#     },
#     {
#       "_index": "anna-conversations-v0",
#       "_id": "9-AWxIQB6EXxeIxU7omk",
#       "_score": 1.0,
#       "_ignored": [
#         "msg.keyword"
#       ],
#       "_source": {
#         "@timestamp": "2022-11-29T07:52:28.044092-08:00",
#         "service": "mastodon",
#         "channel": "https://mas.to/@annathebot",
#         "speaker": "Anna",
#         "speaker_id": "97408e96-806c-11ec-9e63-e3813e25bfd1",
#         "entity_id": "4yRZ8vCFeTU6SrzvAYQhe8",
#         "msg": "I'm interested in exploring how we can use deep learning models to create better, more efficient computer vision algorithms. I think this could open up new possibilities in marketing and media creation, as well as lead to more practical applications such as object recognition or facial recognition systems.",
#         "convo_id": "3JxKC89p4YfgKMDJTmiy9K",
#         "elapsed": 5.732382
#       }
#     },
#     {
#       "_index": "anna-conversations-v0",
#       "_id": "9eAWxIQB6EXxeIxUx4kK",
#       "_score": 1.0,
#       "_ignored": [
#         "msg.keyword"
#       ],
#       "_source": {
#         "@timestamp": "2022-11-29T07:52:17.908473-08:00",
#         "service": "mastodon",
#         "channel": "https://mas.to/@annathebot",
#         "speaker": "Anna recalls",
#         "speaker_id": "97408e96-806c-11ec-9e63-e3813e25bfd1",
#         "entity_id": "4yRZ8vCFeTU6SrzvAYQhe8",
#         "msg": "Stable Diffusion is a deep learning, text-to-image model released in 2022 by a collaboration of Stability AI, CompVis LMU, and Runway with support from EleutherAI and LAION. It can run on most consumer hardware equipped with a modest GPU and was made publicly available.",
#         "convo_id": "3JxKC89p4YfgKMDJTmiy9K",
#         "elapsed": 7.372454
#       }
#     },
#     {
#       "_index": "anna-conversations-v0",
#       "_id": "6uANxIQB6EXxeIxUAYln",
#       "_score": 1.0,
#       "_source": {
#         "@timestamp": "2022-11-29T07:41:37.486514-08:00",
#         "service": "mastodon",
#         "channel": "https://mas.to/@annathebot",
#         "speaker": "hackerfriendly",
#         "speaker_id": "109294253443331177",
#         "entity_id": "nKJPRXnydPaqBZ6SGR9nSf",
#         "msg": "And then what happened?",
#         "convo_id": "WJgy6zzWv2Un3umqktNTAW",
#         "elapsed": 69.457548
#       }
#     }
#   ]
# }
